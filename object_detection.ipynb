# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5 
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks

# upload the custom_dataset.yaml file inside the yolov5/data
# connect the drive
# Out:
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.4/78.2 GB disk)

# %%
# !python train.py --img 640 --batch 2 --epochs 10 --data /content/drive/MyDrive/IIITB/allrect_yolotxt/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/IIITB/allrect_yolotxt/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# detect the formula
#!python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/IIITB/sakura.mp4
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/IIITB/allrect_yolotxt/train/images/10.rf.a71e18e6c266c22c0d9e0989e1f2f8f2.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/IIITB/allrect_yolotxt/train/images/10.rf.a71e18e6c266c22c0d9e0989e1f2f8f2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/.shortcut-targets-by-id/1b4zvTZoQrP0ANduZnHZkJPIX0Q_gpmpo/IIITB/allrect_yolotxt/train/images/10.rf.a71e18e6c266c22c0d9e0989e1f2f8f2.jpg: 640x640 1 people, 16.7ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source vid.mp4 --conf 0.25 --source /content/drive/MyDrive/IIITB/sakura.mp4
#!python detect.py --weights runs/train/exp/weights/best.pt --source img.jpg --conf 0.25 --source /content/drive/MyDrive/CNN/all_objects_yolotxt/test/images/1319item.rf.48d78d862cdc85aec391cfd57a2aecc3.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/IIITB/sakura.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/4447) /content/drive/.shortcut-targets-by-id/1b4zvTZoQrP0ANduZnHZkJPIX0Q_gpmpo/IIITB/sakura.mp4: 384x640 (no detections), 12.1ms
# video 1/1 (2/4447) /content/drive/.shortcut-targets-by-id/1b4zvTZoQrP0ANduZnHZkJPIX0Q_gpmpo/IIITB/sakura.mp4: 384x640 (no detections), 9.0ms
# ...

# %%
#!python detect.py --weights runs/train/exp/weights/best.pt --source vid.mp4 --conf 0.25 --source /content/drive/MyDrive/IIITB/video1.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/IIITB/video1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-47-geab35f6 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/4253) /content/drive/.shortcut-targets-by-id/1b4zvTZoQrP0ANduZnHZkJPIX0Q_gpmpo/IIITB/video1.mp4: 384x640 (no detections), 12.7ms
# video 1/1 (2/4253) /content/drive/.shortcut-targets-by-id/1b4zvTZoQrP0ANduZnHZkJPIX0Q_gpmpo/IIITB/video1.mp4: 384x640 (no detections), 9.7ms
# ...

# %%
#!python detect.py --weights runs/train/exp/weights/best.pt --source vid.mp4 --conf 0.25 --source /content/drive/MyDrive/IIITB/video2.mp4

# %%
#!python detect.py --weights runs/train/exp/weights/best.pt --source vid.mp4 --conf 0.25 --source /content/drive/MyDrive/IIITB/video3.mp4

# %%
#!python detect.py --weights runs/train/exp/weights/best.pt --source vid.mp4 --conf 0.25 --source /content/drive/MyDrive/IIITB/video4.mp4
